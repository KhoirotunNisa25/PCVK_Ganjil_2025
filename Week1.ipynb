# %% [markdown]
# <a href="https://colab.research.google.com/github/KhoirotunNisa25/PCVK_Ganjil_2025/blob/main/Week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Modul 1: Pengantar Citra Digital dan Visi Komputer

# %% [markdown]
# # Praktikum D2

# %% [markdown]
# D2 - Langkah 1: import library

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# %% [markdown]
# D2 - Langkah 2: Baca Image dari URLs

# %%
# Membuat list untuk menyimpan url dari beberapa image
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
        "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
        "https://i.pinimg.com/1200x/b1/dc/34/b1dc34dbb4fcc16d39130278bdf91c4e.jpg"]
# baca dan tampilkan image
# loop pada tiap url image, beberapa image daoat disimpan pada list
for url in urls:
  image = io.imread(url)                          #read image
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5) #resize image to half size
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)  #convert color to RGB
  final_frame = cv.hconcat((image, image_2))      #concatenate image
  cv2_imshow(final_frame)                         #show image
  print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=800x276>
# <PIL.Image.Image image mode=RGB size=800x286>
# <PIL.Image.Image image mode=RGB size=900x424>

# %% [markdown]
# D2 - Langkah 3: Melihat Ukuran File Image

# %%
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print("resolusi image: tinggi x lebar = ",tinggi," x ",lebar)
cv2_imshow(image_2)
# Out:
# resolusi image: tinggi x lebar =  424  x  450
# <PIL.Image.Image image mode=RGB size=450x424>

# %% [markdown]
# D2 - Langka 4: Mengakses Pixel dengan memberi garis diagonal menyilang

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#membuat garis horizontal ditengah image
for y in range (lebar):
  image_3[int((tinggi)/2),y] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=900x424>

# %% [markdown]
# # Pertanyaan Praktikum D2

# %% [markdown]
# 1. Jelaskan, mengapa pada modul praktikum ini eksekusi kode Phyton dilakukan menggunakan Google Colab?
#
# jawab: karena Colab menyediakan lingkungan pemrograman siap pakai, gratis, dan berbasis cloud sehingga mahasiswa tidak perlu repot melakukan instalasi software atau konfigurasi pada komputer pribadi.

# %% [markdown]
# 2. Jelaskan mengenai kegunaan setiap library pada praktikum langkah ke delapan? Apakah semua library tersebut harus digunakan dalam praktikum sesi ini?
#
# Jawab:
#
# *   NumPy: untuk manipulasi array numerik seperti indexing, slicing, iterating, dan reshaping
# *   pandas: digunakan untuk mengelola data berbentuk tabel
# *   cv2 (library utama dari openCV) : digunakan untuk membaca, mengubah ukuran, konversi warna, serta menggambar pada citra.
#     1.   cv.resize() -> memperkecil ukuran gambar.
#     2.   cv.cvtColor() -> mengubah format warna BGR ke RGB.
#     3.   cv.hconcat() -> menggabungkan dua gambar.
#     4.   Menggambar garis horizontal di tengah gambar.
# *   google.colab.patches: fungsi colab khusus untuk menampilkan citra (pada kode cv2_imshow(final_frame))
# *   skimage.io : digunakan untuk membaca gambar dari URL (pada kode io.imread(url))
# *   skimage.transform: Menyediakan fungsi transformasi gambar (resize, rotate, warp, dsb).
# *   PIL (Python Imaging Library): Umumnya digunakan untuk membuka, memproses, dan menyimpan gambar dengan format beragam.
# *   matplotlib.pylab: digunakan untuk plotting grafik dan menampilkan gambar alternatif selain cv2_imshow
#
# ---
#
# Tidak semua library harus digunakan pada praktikum sesi ini. Yang dipakai: cv2, cv2_imshow, skimage.io.

# %% [markdown]
# 3. Pada uji coba langkah ke-9 terdapat potongan kode program sebagai berikut :
# image = cv.resize(image, (0,0), fx=0.5, fy=0.5)
# Apa kegunaan kode program tersebut? dan apa pengaruhnya jika tidak dilakukan?
#
# Jawab:
# *   Kode tersebut digunakan untuk mengubah ukuran (resize) citra menjadi setengah dari ukuran aslinya, fx untuk horizontal (lebar) dan fy untuk vertikal (tinggi). Parameter fx=0.5 dan fy=0.5 berarti skala citra dikurangi 50% dari ukuran asli.
# *   Jika kode tersebut tidak digunakan maka citra akan tetap pada ukuran aslinya (resolusi penuh).

# %% [markdown]
# 4. Perhatikan potongan kode program berikut:
# '#membuat garis horizontal ditengah image
# for y in range (lebar):
#   image_3[int((tinggi)/2),y] = [255,255,255]
# Apakah kegunaan kode [255,255,255]? Jelaskan!
#
# Jawab: Kode [255,255,255] pada baris tersebut merepresentasikan warna putih dalam format warna RGB (Red, Green, Blue), di mana setiap komponen bernilai maksimum (255).

# %% [markdown]
# 5. Jelaskan keterkaitan antara pixel dan juga resolusi gambar yang tinggi ataupun rendah!
#
# Jawab: Pixel adalah unit terkecil penyusun sebuah citra digital yang merepresentasikan satu titik warna. Resolusi menunjukkan jumlah pixel; semakin banyak jumlah pixel (tinggi resolusi) maka gambar semakin tajam dan detail, sedangkan semakin sedikit jumlah pixel (resolusi rendah) membuat gambar terlihat buram atau pecah saat diperbesar.
